# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data =pd.read_csv(r"C:\Users\vardh\Downloads\4289746-671d60a704b57b6d591b02a7b2d48f7b8ec17e1a\4289746-671d60a704b57b6d591b02a7b2d48f7b8ec17e1a\crime.csv")

# %%
df = pd.DataFrame(data)

# %%
data.head()
# Out:
#    Year  Population  Murder  Rape  Robbery  Assault  Burglary  CarTheft
# 0  1965    18073000     836  2320    28182    27464    183443     58452
# 1  1966    18258000     882  2439    30098    29142    196127     64368
# 2  1967    18336000     996  2665    40202    31261    219157     83775
# 3  1968    18113000    1185  2527    59857    34946    250918    104877
# 4  1969    18321000    1324  2902    64754    36890    248477    115400

# %%
print(data)
# Out:
#     Year  Population  Murder  Rape  Robbery  Assault  Burglary  CarTheft
# 0   1965    18073000     836  2320    28182    27464    183443     58452
# 1   1966    18258000     882  2439    30098    29142    196127     64368
# 2   1967    18336000     996  2665    40202    31261    219157     83775
# 3   1968    18113000    1185  2527    59857    34946    250918    104877
# 4   1969    18321000    1324  2902    64754    36890    248477    115400
# 5   1970    18190740    1444  2875    81149    39145    267474    125674
# 6   1971    18391000    1823  3225    97682    42318    273704    127658
# 7   1972    18366000    2026  4199    86391    45926    239886    105081
# 8   1973    18265000    2040  4852    80795    47781    246246    112328
# 9   1974    18111000    1919  5240    86814    51454    271824    104095
# 10  1975    18120000    1996  5099    93499    54593    301996    116274
# 11  1976    18084000    1969  4663    95718    54638    318919    133504
# ...

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['Murder'], bins=50, color='skyblue', edgecolor='black')
plt.xlabel('Murder')
plt.ylabel('Population')
plt.title('Distribution of crimes')
plt.show()

# Summary statistics of ratings count
print(data['Murder'].describe())
# Out:
# count      47.000000
# mean     1549.978723
# std       590.454265
# min       774.000000
# 25%       922.500000
# 50%      1683.000000
# 75%      2016.000000
# max      2605.000000
# Name: Murder, dtype: float64

# %%
plt.figure(figsize=(8, 6))
plt.hist(data['Rape'], bins=50, color='skyblue', edgecolor='black')
plt.xlabel('Rape')
plt.ylabel('Population')
plt.title('Distribution of crimes')
plt.show()

# Summary statistics of ratings count
print(data['Rape'].describe())
# Out:
# count      47.000000
# mean     4200.425532
# std      1096.569507
# min      2320.000000
# 25%      3197.000000
# 50%      4199.000000
# 75%      5241.000000
# max      5706.000000
# Name: Rape, dtype: float64

# %%
plt.figure(figsize=(8, 6))
plt.hist(data['Robbery'], bins=50, color='skyblue', edgecolor='black')
plt.xlabel('Robbery')
plt.ylabel('Population')
plt.title('Distribution of crimes')
plt.show()

# Summary statistics of ratings count
print(data['Robbery'].describe())
# Out:
# count        47.000000
# mean      70429.297872
# std       30204.823764
# min       28141.000000
# 25%       36604.000000
# 50%       81149.000000
# 75%       94141.000000
# max      120344.000000
# Name: Robbery, dtype: float64

# %%
plt.figure(figsize=(8, 6))
plt.hist(data['Assault'], bins=50, color='skyblue', edgecolor='black')
plt.xlabel('Assault')
plt.ylabel('Population')
plt.title('Distribution of crimes')
plt.show()


print(data['Assault'].describe())
# Out:
# count       47.000000
# mean     58022.234043
# std      17455.534367
# min      27464.000000
# 25%      45477.500000
# 50%      57193.000000
# 75%      64864.500000
# max      92105.000000
# Name: Assault, dtype: float64

# %%
plt.figure(figsize=(8, 6))
plt.hist(data['Burglary'], bins=50, color='skyblue', edgecolor='black')
plt.xlabel('Burglary')
plt.ylabel('Population')
plt.title('Distribution of crimes')
plt.show()

# Summary statistics of ratings count
print(data['Burglary'].describe())
# Out:
# count        47.000000
# mean     189119.829787
# std       90256.257143
# min       62769.000000
# 25%       90581.500000
# 50%      208813.000000
# 75%      250016.500000
# max      360925.000000
# Name: Burglary, dtype: float64

# %%
plt.figure(figsize=(8, 6))
plt.hist(data['CarTheft'], bins=50, color='skyblue', edgecolor='black')
plt.xlabel('CarTheft')
plt.ylabel('Population')
plt.title('Distribution of crimes')
plt.show()

print(data['CarTheft'].describe())
# Out:
# count        47.000000
# mean      97573.553191
# std       46707.064488
# min       19311.000000
# 25%       56246.000000
# 50%      106537.000000
# 75%      128367.000000
# max      187591.000000
# Name: CarTheft, dtype: float64

# %%
data['total_crimes'] = data[['Murder', 'Rape', 'Robbery', 'Assault', 'Burglary']].sum(axis=1)

# %%
data.to_csv('updated_data.csv', index=False)

# %%
data.head()
# Out:
#    Year  Population  Murder  Rape  Robbery  Assault  Burglary  CarTheft  \
# 0  1965    18073000     836  2320    28182    27464    183443     58452
# 1  1966    18258000     882  2439    30098    29142    196127     64368
# 2  1967    18336000     996  2665    40202    31261    219157     83775
# 3  1968    18113000    1185  2527    59857    34946    250918    104877
# 4  1969    18321000    1324  2902    64754    36890    248477    115400
#
#    total_crimes
# 0        242245
# 1        258688
# 2        294281
# 3        349433
# 4        354347

# %%
total_crimes = data[['Murder', 'Rape', 'Robbery', 'Assault', 'Burglary']].sum()

# %%
plt.figure(figsize=(8, 8))
plt.pie(total_crimes, labels=total_crimes.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Rates')
plt.show()

# %%
data['murder_cases'] = data['Population'] - data['Murder']

# %%
print(data['murder_cases'])
# Out:
# 0     18072164
# 1     18257118
# 2     18335004
# 3     18111815
# 4     18319676
# 5     18189296
# 6     18389177
# 7     18363974
# 8     18262960
# 9     18109081
# 10    18118004
# 11    18082031
# 12    17922081
# 13    17746180
# 14    17646908
# 15    17504462
# 16    17591834
# 17    17656987
# 18    17665042
# 19    17733214
# 20    17781317
# 21    17770093
# 22    17822984
# 23    17895756
# 24    17947754
# 25    17987850
# 26    18055429
# 27    18116603
# 28    18194580
# 29    18166984
# 30    18134450
# 31    18183647
# 32    18135907
# 33    18174076
# 34    18195698
# 35    18975505
# 36    19083390
# 37    19133384
# 38    19211491
# 39    19279838
# 40    19314847
# 41    19305262
# 42    19296928
# 43    19466953
# 44    19540672
# 45    19394338
# 46    19464423
# Name: murder_cases, dtype: int64

# %%
data['rape_cases'] = data['Population'] - data['Rape']

# %%
print(data['rape_cases'])
# Out:
# 0     18070680
# 1     18255561
# 2     18333335
# 3     18110473
# 4     18318098
# 5     18187865
# 6     18387775
# 7     18361801
# 8     18260148
# 9     18105760
# 10    18114901
# 11    18079337
# 12    17918728
# 13    17742832
# 14    17643606
# 15    17501285
# 16    17588521
# 17    17653841
# 18    17661704
# 19    17729401
# 20    17777294
# 21    17766585
# 22    17819463
# 23    17892521
# 24    17944758
# 25    17985087
# 26    18052915
# 27    18113848
# 28    18191992
# 29    18164300
# 30    18131710
# 31    18180826
# 32    18132925
# 33    18171157
# 34    18193038
# 35    18972927
# 36    19080804
# 37    19130408
# 38    19208650
# 39    19277119
# 40    19312085
# 41    19303014
# 42    19294803
# 43    19464990
# 44    19538871
# 45    19392409
# 46    19462445
# Name: rape_cases, dtype: int64

# %%
data['robbery_cases'] = data['Population'] - data['Robbery']

# %%
print(data['robbery_cases'])
# Out:
# 0     18044818
# 1     18227902
# 2     18295798
# 3     18053143
# 4     18256246
# 5     18109591
# 6     18293318
# 7     18279609
# 8     18184205
# 9     18024186
# 10    18026501
# 11    17988282
# 12    17839297
# 13    17664215
# 14    17555529
# 15    17394417
# 16    17473656
# 17    17551157
# 18    17572217
# 19    17645100
# 20    17693294
# 21    17680640
# 22    17735279
# 23    17800566
# 24    17846017
# 25    17878075
# 26    17945658
# 27    18010846
# 28    18094878
# 29    18082383
# 30    18063508
# 31    18123178
# 32    18080906
# 33    18125875
# 34    18152780
# 35    18935918
# 36    19047795
# 37    19097640
# 38    19176635
# 39    19247221
# 40    19280542
# 41    19271694
# 42    19266635
# 43    19436000
# 44    19513312
# 45    19366576
# 46    19436801
# Name: robbery_cases, dtype: int64

# %%
data['assault_cases'] = data['Population'] - data['Assault']

# %%
print(data['murder_cases'])
# Out:
# 0     18070680
# 1     18255561
# 2     18333335
# 3     18110473
# 4     18318098
# 5     18187865
# 6     18387775
# 7     18361801
# 8     18260148
# 9     18105760
# 10    18114901
# 11    18079337
# 12    17918728
# 13    17742832
# 14    17643606
# 15    17501285
# 16    17588521
# 17    17653841
# 18    17661704
# 19    17729401
# 20    17777294
# 21    17766585
# 22    17819463
# 23    17892521
# 24    17944758
# 25    17985087
# 26    18052915
# 27    18113848
# 28    18191992
# 29    18164300
# 30    18131710
# 31    18180826
# 32    18132925
# 33    18171157
# 34    18193038
# 35    18972927
# 36    19080804
# 37    19130408
# 38    19208650
# 39    19277119
# 40    19312085
# 41    19303014
# 42    19294803
# 43    19464990
# 44    19538871
# 45    19392409
# 46    19462445
# Name: murder_cases, dtype: int64

# %%
data['burglary_cases'] = data['Population'] - data['Burglary']

# %%
print(data['burglary_cases'])
# Out:
# 0     17889557
# 1     18061873
# 2     18116843
# 3     17862082
# 4     18072523
# 5     17923266
# 6     18117296
# 7     18126114
# 8     18018754
# 9     17839176
# 10    17818004
# 11    17765081
# 12    17614265
# 13    17455044
# 14    17340698
# 15    17145765
# 16    17243578
# 17    17363755
# 18    17417885
# 19    17512044
# 20    17563367
# 21    17554990
# 22    17608174
# 23    17679940
# 24    17738870
# 25    17781642
# 26    17853501
# 27    17925452
# 28    18015291
# 29    18004350
# 30    17989438
# 31    18055172
# 32    18018694
# 33    18070179
# 34    18103384
# 35    18888511
# 36    19003950
# 37    19057593
# 38    19136972
# 39    19210031
# 40    19247687
# 41    19237618
# 42    19232872
# 43    19402252
# 44    19478684
# 45    19329367
# 46    19399800
# Name: burglary_cases, dtype: int64

# %%
data['CarTheft_cases'] = data['Population'] - data['CarTheft']

# %%
print(data['CarTheft_cases'])
# Out:
# 0     18014548
# 1     18193632
# 2     18252225
# 3     18008123
# 4     18205600
# 5     18065066
# 6     18263342
# 7     18260919
# 8     18152672
# 9     18006905
# 10    18003726
# 11    17950496
# 12    17790331
# 13    17628736
# 14    17524657
# 15    17373649
# 16    17457151
# 17    17521120
# 18    17539139
# 19    17619608
# 20    17676463
# 21    17658753
# 22    17699671
# 23    17744102
# 24    17778993
# 25    17802864
# 26    17876713
# 27    17950078
# 28    18045051
# 29    18040127
# 30    18033404
# 31    18095100
# 32    18057303
# 33    18106829
# 34    18138340
# 35    18922226
# 36    19036063
# 37    19086927
# 38    19167221
# 39    19239725
# 40    19279985
# 41    19274049
# 42    19269699
# 43    19442693
# 44    19519582
# 45    19374567
# 46    19445886
# Name: CarTheft_cases, dtype: int64
